# %% [markdown]
# # Test Notebook with Errors
#
# This notebook tests error handling and display in cell results.

# %%
# Cell 1: Success
print("Hello, World!")
x = 42
print(f"x = {x}")

# %%
# Cell 2: Success
import math
result = math.sqrt(16)
print(f"Square root of 16 is {result}")

# %%
# Cell 3: Division by Zero Error
numerator = 100
denominator = 0
result = numerator / denominator
print(f"Result: {result}")

# %%
# Cell 4: This should not execute due to previous error
print("This cell should not execute")
